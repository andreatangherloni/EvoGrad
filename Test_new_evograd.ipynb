# %%
from evograd.core.problem import Problem
from evograd.core.minimize import minimize
from evograd.core.maximize import maximize

from evograd.core.termination import MaxEvaluations
from evograd.operators import TournamentSelection, SBXCrossover, PolynomialMutation, ReflectRepair
from evograd.algorithms.ga import GA
from evograd.algorithms.de import DE
from evograd.algorithms.pso import PSO
from evograd.algorithms.cmaes import CMAES

# %%
problem = Problem(
    objective=lambda x: (x ** 2).sum(dim=-1),  # Sphere function
    n_var=10,
    xl=-5.0,
    xu=5.0,
)

# %% [markdown]
# # Test GA differentiability

# %%
algorithm = GA(pop_size=100,
               selection=TournamentSelection(tournament_size=3, differentiable=False),
               crossover=SBXCrossover(eta=15, prob=0.9, differentiable=False),
               mutation=PolynomialMutation(eta=20, differentiable=False),
               differentiable=False,
               )

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
print("Diff cr? ", algorithm.crossover.eta.requires_grad)
print("Diff mt? ", algorithm.mutation.eta.requires_grad)
# Out:
# Diff pop? False
# Diff sl?  False
# Diff cr?  False
# Diff mt?  False

# %%
algorithm = GA(pop_size=100,
               selection=TournamentSelection(tournament_size=3, differentiable=True),
               crossover=SBXCrossover(eta=15, prob=0.9, differentiable=True),
               mutation=PolynomialMutation(eta=20, differentiable=True),
               differentiable=False,
               )

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
print("Diff cr? ", algorithm.crossover.eta.requires_grad)
print("Diff mt? ", algorithm.mutation.eta.requires_grad)
# Out:
# Diff pop? False
# Diff sl?  True
# Diff cr?  True
# Diff mt?  True

# %%
algorithm = GA(pop_size=100,
               selection=TournamentSelection(tournament_size=3, differentiable=False),
               crossover=SBXCrossover(eta=15, prob=0.9, differentiable=False),
               mutation=PolynomialMutation(eta=20, differentiable=False),
               differentiable=True,
               )

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
print("Diff cr? ", algorithm.crossover.eta.requires_grad)
print("Diff mt? ", algorithm.mutation.eta.requires_grad)
# Out:
# Diff pop? True
# Diff sl?  False
# Diff cr?  False
# Diff mt?  False

# %%
algorithm = GA(pop_size=100,
               selection=TournamentSelection(tournament_size=3, differentiable=True),
               crossover=SBXCrossover(eta=15, prob=0.9, differentiable=True),
               mutation=PolynomialMutation(eta=20, differentiable=True),
               differentiable=True,
               )

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
print("Diff cr? ", algorithm.crossover.eta.requires_grad)
print("Diff mt? ", algorithm.mutation.eta.requires_grad)
# Out:
# Diff pop? True
# Diff sl?  True
# Diff cr?  True
# Diff mt?  True

# %% [markdown]
# # Test DE differentiability

# %%
algorithm = DE(pop_size=100,
               variant="DE/rand/1/bin",
               F=0.5,
               CR=0.9,
               adaptive=False,
               differentiable=False)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cr? ", algorithm.crossover.cr.requires_grad)
# print("Diff mt? ", algorithm.mutation.eta.requires_grad)
# Out:
# Diff pop? False
# Diff cr?  False

# %%
algorithm = DE(pop_size=100,
               variant="DE/rand/1/bin",
               F=0.5,
               CR=0.9,
               adaptive=False,
               differentiable=False)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cr? ", algorithm.crossover.cr.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
# Out:
# Diff pop? False
# Diff cr?  False
# Diff sl?  False

# %%
algorithm = DE(pop_size=100,
               variant="DE/rand/1/bin",
               F=0.5,
               CR=0.9,
               adaptive=True,
               differentiable=False)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cr? ", algorithm.crossover.cr.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
# Out:
# Diff pop? False
# Diff cr?  True
# Diff sl?  True

# %%
algorithm = DE(pop_size=100,
               variant="DE/rand/1/bin",
               F=0.5,
               CR=0.9,
               adaptive=False,
               differentiable=True)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cr? ", algorithm.crossover.cr.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
# Out:
# Diff pop? True
# Diff cr?  False
# Diff sl?  False

# %%
algorithm = DE(pop_size=100,
               variant="DE/rand/1/bin",
               F=0.5,
               CR=0.9,
               adaptive=True,
               differentiable=True)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cr? ", algorithm.crossover.cr.requires_grad)
print("Diff sl? ", algorithm.selection.temperature.requires_grad)
# Out:
# Diff pop? True
# Diff cr?  True
# Diff sl?  True

# %% [markdown]
# # Test PSO differentiability

# %%
algorithm = PSO(pop_size=100,
                inertia=0.7,
                c1=1.5,
                c2=1.5,
                adaptive=False,
                differentiable=False)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff c1? ", algorithm.c1.requires_grad)
print("Diff c2? ", algorithm.c2.requires_grad)
print("Diff w?  ", algorithm.inertia.requires_grad)
# Out:
# Diff pop? False
# Diff c1?  False
# Diff c2?  False
# Diff w?   False

# %%
algorithm = PSO(pop_size=100,
                inertia=0.7,
                c1=1.5,
                c2=1.5,
                adaptive=True,
                differentiable=False)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff c1? ", algorithm.c1.requires_grad)
print("Diff c2? ", algorithm.c2.requires_grad)
print("Diff w?  ", algorithm.inertia.requires_grad)
# Out:
# Diff pop? False
# Diff c1?  True
# Diff c2?  True
# Diff w?   True

# %%
algorithm = PSO(pop_size=100,
                inertia=0.7,
                c1=1.5,
                c2=1.5,
                adaptive=False,
                differentiable=True)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff c1? ", algorithm.c1.requires_grad)
print("Diff c2? ", algorithm.c2.requires_grad)
print("Diff w?  ", algorithm.inertia.requires_grad)
# Out:
# Diff pop? True
# Diff c1?  False
# Diff c2?  False
# Diff w?   False

# %%
algorithm = PSO(pop_size=100,
                inertia=0.7,
                c1=1.5,
                c2=1.5,
                adaptive=True,
                differentiable=True)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff c1? ", algorithm.c1.requires_grad)
print("Diff c2? ", algorithm.c2.requires_grad)
print("Diff w?  ", algorithm.inertia.requires_grad)
algorithm.c1.grad
# Out:
# Diff pop? True
# Diff c1?  True
# Diff c2?  True
# Diff w?   True
# tensor(-0.0470, device='mps:0')

# %%
algorithm = PSO(pop_size=100,
                inertia=0.7,
                c1=1.5,
                c2=1.5,
                adaptive=True,
                per_particle_coeffs=True,
                differentiable=True)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff c1? ", algorithm.c1.requires_grad)
print("Diff c2? ", algorithm.c2.requires_grad)
print("Diff w?  ", algorithm.inertia.requires_grad)
# Out:
# Diff pop? True
# Diff c1?  True
# Diff c2?  True
# Diff w?   True

# %% [markdown]
# # Test CMAES differentiability

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=False,
                  differentiable=False,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cmu?", algorithm.cmu.requires_grad)
# Out:
# Diff pop? False
# Diff cmu? False

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=True,
                  differentiable=False,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cmu?", algorithm.cmu.requires_grad)
# Out:
# Diff pop? False
# Diff cmu? True

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=False,
                  differentiable=True,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cmu?", algorithm.cmu.requires_grad)
# Out:
# Diff pop? True
# Diff cmu? False

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=True,
                  differentiable=True,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(1000),
                  seed=42,
                  verbose=False)

print("Diff pop?", algorithm.population.requires_grad)
print("Diff cmu?", algorithm.cmu.requires_grad)
# Out:
# Diff pop? True
# Diff cmu? True

# %%
import torch
def ackley(x, a=20, b=0.2, c=2 * torch.pi):
    # x = x.to(device)

    d = x.size(1)
    sum_sq_term = torch.sum(x ** 2, dim=-1) / d
    cos_term = torch.sum(torch.cos(c * x), dim=-1) / d

    term1 = -a * torch.exp(-b * torch.sqrt(sum_sq_term))
    term2 = -torch.exp(cos_term)

    return term1 + term2 + a + torch.exp(torch.tensor(1.0, device=x.device))

# %%
problem = Problem(
    objective=ackley,
    n_var=100,
    xl=-100.0,
    xu=100.0,
)

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=False,
                  differentiable=False,
                  restarts=9,
                  bipop=True,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 3.175799e+00 | Evals:     200 | Time: 0.00s
# Gen     2 | Best: 3.175799e+00 | Evals:     300 | Time: 0.01s
# Gen     3 | Best: 2.999631e+00 | Evals:     400 | Time: 0.01s
# Gen     4 | Best: 2.999631e+00 | Evals:     500 | Time: 0.01s
# Gen     5 | Best: 2.823770e+00 | Evals:     600 | Time: 0.01s
# Gen     6 | Best: 2.663640e+00 | Evals:     700 | Time: 0.02s
# Gen     7 | Best: 2.663283e+00 | Evals:     800 | Time: 0.02s
# Gen     8 | Best: 2.663283e+00 | Evals:     900 | Time: 0.02s
# Gen     9 | Best: 2.663283e+00 | Evals:    1000 | Time: 0.03s
# Gen    10 | Best: 2.509048e+00 | Evals:    1100 | Time: 0.03s
# Gen    11 | Best: 2.509048e+00 | Evals:    1200 | Time: 0.03s
# Gen    12 | Best: 2.260556e+00 | Evals:    1300 | Time: 0.03s
# Gen    13 | Best: 2.260556e+00 | Evals:    1400 | Time: 0.04s
# ...

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=True,
                  differentiable=False,
                  restarts=9,
                  bipop=True,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 3.175799e+00 | Evals:     200 | Time: 0.03s
# Gen     2 | Best: 3.175799e+00 | Evals:     300 | Time: 0.04s
# Gen     3 | Best: 2.972068e+00 | Evals:     400 | Time: 0.04s
# Gen     4 | Best: 2.972068e+00 | Evals:     500 | Time: 0.05s
# Gen     5 | Best: 2.806678e+00 | Evals:     600 | Time: 0.06s
# Gen     6 | Best: 2.664084e+00 | Evals:     700 | Time: 0.06s
# Gen     7 | Best: 2.621369e+00 | Evals:     800 | Time: 0.07s
# Gen     8 | Best: 2.621369e+00 | Evals:     900 | Time: 0.08s
# Gen     9 | Best: 2.557237e+00 | Evals:    1000 | Time: 0.09s
# Gen    10 | Best: 2.516978e+00 | Evals:    1100 | Time: 0.09s
# Gen    11 | Best: 2.511510e+00 | Evals:    1200 | Time: 0.10s
# Gen    12 | Best: 2.256793e+00 | Evals:    1300 | Time: 0.10s
# Gen    13 | Best: 2.254661e+00 | Evals:    1400 | Time: 0.11s
# ...

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=False,
                  differentiable=True,
                  restarts=9,
                  bipop=True,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 3.175799e+00 | Evals:     200 | Time: 0.01s
# Gen     2 | Best: 3.175799e+00 | Evals:     300 | Time: 0.01s
# Gen     3 | Best: 3.001534e+00 | Evals:     400 | Time: 0.02s
# Gen     4 | Best: 3.001534e+00 | Evals:     500 | Time: 0.02s
# Gen     5 | Best: 2.794551e+00 | Evals:     600 | Time: 0.03s
# Gen     6 | Best: 2.662530e+00 | Evals:     700 | Time: 0.04s
# Gen     7 | Best: 2.661777e+00 | Evals:     800 | Time: 0.04s
# Gen     8 | Best: 2.661777e+00 | Evals:     900 | Time: 0.05s
# Gen     9 | Best: 2.661777e+00 | Evals:    1000 | Time: 0.06s
# Gen    10 | Best: 2.483293e+00 | Evals:    1100 | Time: 0.06s
# Gen    11 | Best: 2.483293e+00 | Evals:    1200 | Time: 0.07s
# Gen    12 | Best: 2.198148e+00 | Evals:    1300 | Time: 0.08s
# Gen    13 | Best: 2.198148e+00 | Evals:    1400 | Time: 0.08s
# ...

# %%
algorithm = CMAES(pop_size=100,
                  sigma=0.5,
                  adaptive=True,
                  differentiable=True,
                  restarts=9,
                  bipop=True,
                  device="cpu")

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 3.175799e+00 | Evals:     200 | Time: 0.01s
# Gen     2 | Best: 3.175799e+00 | Evals:     300 | Time: 0.02s
# Gen     3 | Best: 2.966069e+00 | Evals:     400 | Time: 0.02s
# Gen     4 | Best: 2.966069e+00 | Evals:     500 | Time: 0.03s
# Gen     5 | Best: 2.777715e+00 | Evals:     600 | Time: 0.04s
# Gen     6 | Best: 2.671227e+00 | Evals:     700 | Time: 0.04s
# Gen     7 | Best: 2.624450e+00 | Evals:     800 | Time: 0.05s
# Gen     8 | Best: 2.624450e+00 | Evals:     900 | Time: 0.05s
# Gen     9 | Best: 2.540069e+00 | Evals:    1000 | Time: 0.06s
# Gen    10 | Best: 2.501271e+00 | Evals:    1100 | Time: 0.07s
# Gen    11 | Best: 2.471591e+00 | Evals:    1200 | Time: 0.07s
# Gen    12 | Best: 2.205283e+00 | Evals:    1300 | Time: 0.08s
# Gen    13 | Best: 2.196342e+00 | Evals:    1400 | Time: 0.08s
# ...

# %%
algorithm = GA(pop_size=100,
               selection=TournamentSelection(tournament_size=3, differentiable=True),
               crossover=SBXCrossover(eta=15, prob=0.9, differentiable=True),
               mutation=PolynomialMutation(eta=20, differentiable=True),
               differentiable=True,
               )

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 2.151125e+01 | Evals:     200 | Time: 0.19s
# Gen     2 | Best: 2.151125e+01 | Evals:     300 | Time: 0.25s
# Gen     3 | Best: 2.151125e+01 | Evals:     400 | Time: 0.31s
# Gen     4 | Best: 2.151125e+01 | Evals:     500 | Time: 0.38s
# Gen     5 | Best: 2.150169e+01 | Evals:     600 | Time: 0.44s
# Gen     6 | Best: 2.150169e+01 | Evals:     700 | Time: 0.50s
# Gen     7 | Best: 2.144867e+01 | Evals:     800 | Time: 0.56s
# Gen     8 | Best: 2.144867e+01 | Evals:     900 | Time: 0.64s
# Gen     9 | Best: 2.144867e+01 | Evals:    1000 | Time: 0.73s
# Gen    10 | Best: 2.144867e+01 | Evals:    1100 | Time: 0.80s
# Gen    11 | Best: 2.144867e+01 | Evals:    1200 | Time: 0.87s
# Gen    12 | Best: 2.144867e+01 | Evals:    1300 | Time: 0.93s
# Gen    13 | Best: 2.144867e+01 | Evals:    1400 | Time: 0.99s
# ...

# %%
algorithm = DE(pop_size=100,
               variant="DE/rand/1/bin",
               F=0.5,
               CR=0.9,
               adaptive=True,
               differentiable=True)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 2.133931e+01 | Evals:     200 | Time: 0.06s
# Gen     2 | Best: 2.121817e+01 | Evals:     300 | Time: 0.08s
# Gen     3 | Best: 2.117276e+01 | Evals:     400 | Time: 0.10s
# Gen     4 | Best: 2.111987e+01 | Evals:     500 | Time: 0.11s
# Gen     5 | Best: 2.097129e+01 | Evals:     600 | Time: 0.13s
# Gen     6 | Best: 2.097129e+01 | Evals:     700 | Time: 0.15s
# Gen     7 | Best: 2.072437e+01 | Evals:     800 | Time: 0.16s
# Gen     8 | Best: 2.060287e+01 | Evals:     900 | Time: 0.18s
# Gen     9 | Best: 2.059563e+01 | Evals:    1000 | Time: 0.20s
# Gen    10 | Best: 2.046335e+01 | Evals:    1100 | Time: 0.25s
# Gen    11 | Best: 2.046335e+01 | Evals:    1200 | Time: 0.27s
# Gen    12 | Best: 2.046335e+01 | Evals:    1300 | Time: 0.29s
# Gen    13 | Best: 2.037589e+01 | Evals:    1400 | Time: 0.31s
# ...

# %%
algorithm = PSO(pop_size=100,
                inertia=0.7,
                c1=1.5,
                c2=1.5,
                adaptive=True,
                differentiable=True)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 2.152861e+01 | Evals:     200 | Time: 0.06s
# Gen     2 | Best: 2.149631e+01 | Evals:     300 | Time: 0.07s
# Gen     3 | Best: 2.149631e+01 | Evals:     400 | Time: 0.08s
# Gen     4 | Best: 2.149631e+01 | Evals:     500 | Time: 0.09s
# Gen     5 | Best: 2.149631e+01 | Evals:     600 | Time: 0.11s
# Gen     6 | Best: 2.149631e+01 | Evals:     700 | Time: 0.12s
# Gen     7 | Best: 2.149631e+01 | Evals:     800 | Time: 0.13s
# Gen     8 | Best: 2.149631e+01 | Evals:     900 | Time: 0.17s
# Gen     9 | Best: 2.149631e+01 | Evals:    1000 | Time: 0.19s
# Gen    10 | Best: 2.149631e+01 | Evals:    1100 | Time: 0.20s
# Gen    11 | Best: 2.149631e+01 | Evals:    1200 | Time: 0.21s
# Gen    12 | Best: 2.146277e+01 | Evals:    1300 | Time: 0.22s
# Gen    13 | Best: 2.146277e+01 | Evals:    1400 | Time: 0.23s
# ...

# %%
algorithm = PSO(pop_size=100,
                inertia=0.7,
                c1=1.5,
                c2=1.5,
                adaptive=False,
                differentiable=False)

result = minimize(problem,
                  algorithm,
                  termination=MaxEvaluations(10000),
                  seed=42,
                  verbose=True)
# Out:
# ---------------------------------
# Gen | Best Fitness | Evals | Time
# ---------------------------------
# Gen     1 | Best: 2.152861e+01 | Evals:     200 | Time: 0.01s
# Gen     2 | Best: 2.150603e+01 | Evals:     300 | Time: 0.01s
# Gen     3 | Best: 2.149241e+01 | Evals:     400 | Time: 0.02s
# Gen     4 | Best: 2.143053e+01 | Evals:     500 | Time: 0.02s
# Gen     5 | Best: 2.143053e+01 | Evals:     600 | Time: 0.03s
# Gen     6 | Best: 2.143053e+01 | Evals:     700 | Time: 0.04s
# Gen     7 | Best: 2.143053e+01 | Evals:     800 | Time: 0.04s
# Gen     8 | Best: 2.143053e+01 | Evals:     900 | Time: 0.05s
# Gen     9 | Best: 2.143053e+01 | Evals:    1000 | Time: 0.06s
# Gen    10 | Best: 2.143053e+01 | Evals:    1100 | Time: 0.06s
# Gen    11 | Best: 2.143053e+01 | Evals:    1200 | Time: 0.07s
# Gen    12 | Best: 2.143053e+01 | Evals:    1300 | Time: 0.08s
# Gen    13 | Best: 2.143053e+01 | Evals:    1400 | Time: 0.08s
# ...
